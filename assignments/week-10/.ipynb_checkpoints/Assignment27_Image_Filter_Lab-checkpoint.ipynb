# %% [markdown]
# # Assignment 27 – Image Filter Lab
# Date: 08-04-2026
#
# ---
#
# ## Problem Statement
#
# Apply preprocessing techniques such as grayscale conversion, blurring, and edge detection on an image.
#
# ---
#
# ## Code

# %%
import cv2
import urllib.request
import matplotlib.pyplot as plt

# download image
url = "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg"
urllib.request.urlretrieve(url, "sample.jpg")

image = cv2.imread("sample.jpg")

# convert to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# blur
blur = cv2.GaussianBlur(gray,(5,5),0)

# edge detection
edges = cv2.Canny(blur,50,150)

# display images
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")
plt.show()

plt.imshow(gray, cmap="gray")
plt.title("Grayscale")
plt.axis("off")
plt.show()

plt.imshow(blur, cmap="gray")
plt.title("Blur")
plt.axis("off")
plt.show()

plt.imshow(edges, cmap="gray")
plt.title("Edges")
plt.axis("off")
plt.show()

# %% [markdown]
# ---
#
# ## Concepts Used
#
# Image preprocessing\
# Grayscale conversion\
# Image smoothing\
# Edge detection
#
# ---
#
# ## Key Learnings
#
# Filters improve image quality\
# Edge detection highlights boundaries\
# Preprocessing helps feature extraction
#
# ---
#
# ## Applications
#
# Face recognition\
# Medical diagnosis\
# Object detection\
# Self driving cars
#
# ---
#
# ## Conclusion
#
# Image filtering improves feature extraction and helps machine learning models perform better.
