# %% [markdown]
# # Assignment 28 – Detection Brainstorm
# Date: 10-04-2026
#
# ---
#
# ## Problem Statement
#
# List applications of face or object detection and design one basic detection solution.
#
# ---
#
# ## Code

# %%
import cv2
import urllib.request
import matplotlib.pyplot as plt

# download face image
url = "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg"
urllib.request.urlretrieve(url, "face.jpg")

# load model
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# read image
image = cv2.imread("face.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray,1.1,5)

# draw rectangle
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

# convert to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# show image
plt.imshow(image_rgb)
plt.title("Face Detection")
plt.axis("off")
plt.show()

print("Faces detected:", len(faces))
# Out:
# Faces detected: 1

# %% [markdown]
# ---
#
# ## Concepts Used
#
# Object detection\
# Face detection\
# Haar cascade classifier\
# Computer vision
#
# ---
#
# ## Key Learnings
#
# Object detection identifies items in images\
# Face detection is widely used in security\
# Models detect patterns using trained data
#
# ---
#
# ## Applications
#
# Attendance systems\
# Phone unlock\
# Surveillance systems\
# Self driving cars\
# Retail analytics
#
# ---
#
# ## Conclusion
#
# Object detection helps automate identification tasks in real-world applications.
