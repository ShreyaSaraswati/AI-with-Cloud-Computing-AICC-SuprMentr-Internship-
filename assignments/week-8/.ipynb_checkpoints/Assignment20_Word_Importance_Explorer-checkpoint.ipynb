# %% [markdown]
# # Assignment 20 – Word Importance Explorer
# Date: 24-03-2026
#
# ---
#
# ## Problem Statement
#
# Use TF-IDF on 5 documents to identify important words.
#
# TF-IDF helps find words that are important in a document but not too common across all documents.
#
# ---
#
# ## Sample Text Documents
# Machine learning improves prediction accuracy\
# Artificial intelligence and machine learning are related\
# Python is used in data science\
# Data science uses machine learning techniques\
# ai is transforming modern technology
#
# ---
#
# ## Code

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "machine learning improves prediction accuracy",
    "artificial intelligence and machine learning are related",
    "python is used in data science",
    "data science uses machine learning techniques",
    "ai is transforming modern technology"
]

vectorizer = TfidfVectorizer(stop_words="english")

tfidf_matrix = vectorizer.fit_transform(documents)

feature_names = vectorizer.get_feature_names_out()

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=feature_names
)

print(tfidf_df)
# Out:
#    accuracy   ai  artificial      data  improves  intelligence  learning  \
# 0  0.506563  0.0    0.000000  0.000000  0.506563      0.000000  0.339251
# 1  0.000000  0.0    0.506563  0.000000  0.000000      0.506563  0.339251
# 2  0.000000  0.0    0.000000  0.444002  0.000000      0.000000  0.000000
# 3  0.000000  0.0    0.000000  0.393728  0.000000      0.000000  0.326830
# 4  0.000000  0.5    0.000000  0.000000  0.000000      0.000000  0.000000
#
#     machine  modern  prediction    python   related   science  techniques  \
# 0  0.339251     0.0    0.506563  0.000000  0.000000  0.000000    0.000000
# 1  0.339251     0.0    0.000000  0.000000  0.506563  0.000000    0.000000
# 2  0.000000     0.0    0.000000  0.550329  0.000000  0.444002    0.000000
# 3  0.326830     0.0    0.000000  0.000000  0.000000  0.393728    0.488016
# 4  0.000000     0.5    0.000000  0.000000  0.000000  0.000000    0.000000
#
#    technology  transforming      used      uses
# ...

# %% [markdown]
# ---
#
# ## Concepts Used
# TF-IDF\
# Feature extraction\
# Text importance\
# NLP preprocessing\
# Document analysis
#
# ---
#
# ## Key Learnings
# TF-IDF helps identify meaningful words\
# Common words have low importance\
# Useful for search engines and classification\
# Helps summarize documents
#
# ---
#
# ## Applications
# Keyword extraction\
# Search engines\
# Document clustering\
# Resume screening\
# Topic identification
#
# ---
#
# ## Conclusion
#
# TF-IDF helps identify important words and improves understanding of text data.
